# %% [markdown]
# **Group-5**
#
# 1) Ritwik Kashyap 2021485
#
# 2) Tanishq Tiwari 2021496
#
# 3) Tanuj Kamboj  2021497

# %% [markdown]
# Question 1 (5 points)
# Take a string of 10 nucleotides as input. Write a code to produce all possible strings with 0 or 1 or
# 2 mutations. Use these new strings for constructing a consensus string. Find the Hamming distance
# between the starting string and the consensus string. Also, write down the formula for the number of
# strings with 0, 1, 2 mutations.

# %% [markdown]
# STEP 1:
# we have to find the strings with 0 , 1 and 2 mutations
# >
# for 0 mutations the mutated string is same as original sequence
# >
# for 1 mutation each nucleotide of the original sequence is replaced by the the other three combinations of nucleotides to make a new mutated sequence
# >
# for 2 mutations we will take all possibe pairs of 2 nucleotides and replace them with the other 2 remaining nucleotides in all possible way

# %%
# here are the formulas for calculating the number of mutated strings mathematically

original_sequence = input("Enter a string : ")
nucleotides = ['A' , 'T' , 'G' , 'C']
mutated_sequences = []
mutated_sequences.append(original_sequence) # for 0 mutations

print("strings with 0 mutations : " , len(mutated_sequences) , " " , mutated_sequences)

# n: The length of the original sequence (number of positions).
# N: The total number of nucleotides (4 for DNA: A, T, G, C).
# Number of Strings with 1 Mutation:
# Formula: n * (N - 1)   =  n*3 =   30 for original sequence of length 10

for i in range(len(original_sequence)):   # for 1 mutation
  for j in nucleotides:
    if(j == original_sequence[i]):
      continue
    temp = list(original_sequence)
    temp[i] = j
    mutated_sequences.append("".join(temp))

print("strings with 1 mutations : " , len(mutated_sequences) , " " , mutated_sequences)

# 10c2*3*3 = 45x9 = 405 possible strings for original sequence of length 10

for i in range(len(original_sequence)):  # for 2 mutations
    for j in range(i + 1, len(original_sequence)):
        for nucleotide1 in nucleotides:
            for nucleotide2 in nucleotides:
                if(nucleotide1 != original_sequence[i] and nucleotide2 != original_sequence[j]):
                  temp = list(original_sequence)
                  temp[i] = nucleotide1
                  temp[j] = nucleotide2
                  mutated_sequences.append("".join(temp))


print("strings with 2 mutations : " , len(mutated_sequences) , " " , mutated_sequences)
# Out:
# Enter a string : ATGC
# strings with 0 mutations :  1   ['ATGC']
# strings with 1 mutations :  13   ['ATGC', 'TTGC', 'GTGC', 'CTGC', 'AAGC', 'AGGC', 'ACGC', 'ATAC', 'ATTC', 'ATCC', 'ATGA', 'ATGT', 'ATGG']
# strings with 2 mutations :  67   ['ATGC', 'TTGC', 'GTGC', 'CTGC', 'AAGC', 'AGGC', 'ACGC', 'ATAC', 'ATTC', 'ATCC', 'ATGA', 'ATGT', 'ATGG', 'TAGC', 'TGGC', 'TCGC', 'GAGC', 'GGGC', 'GCGC', 'CAGC', 'CGGC', 'CCGC', 'TTAC', 'TTTC', 'TTCC', 'GTAC', 'GTTC', 'GTCC', 'CTAC', 'CTTC', 'CTCC', 'TTGA', 'TTGT', 'TTGG', 'GTGA', 'GTGT', 'GTGG', 'CTGA', 'CTGT', 'CTGG', 'AAAC', 'AATC', 'AACC', 'AGAC', 'AGTC', 'AGCC', 'ACAC', 'ACTC', 'ACCC', 'AAGA', 'AAGT', 'AAGG', 'AGGA', 'AGGT', 'AGGG', 'ACGA', 'ACGT', 'ACGG', 'ATAA', 'ATAT', 'ATAG', 'ATTA', 'ATTT', 'ATTG', 'ATCA', 'ATCT', 'ATCG']

# %%
# Step 2: Now We will find consensus string of the all the mutated sequence

consensus_sequence = ""
for i in range(len(original_sequence)): #
  count_A = 0
  count_T = 0
  count_G = 0
  count_C = 0
  for j in mutated_sequences:
    if j[i] == 'A':
        count_A += 1
    elif j[i] == 'T':
        count_T += 1
    elif j[i] == 'G':
        count_G += 1
    elif j[i] == 'C':
        count_C += 1

  max_nucleotide = 'A'
  max = count_A
  if count_T > max:
      max_nucleotide = 'T'
      max = count_T
  if count_G > max:
      max_nucleotide = 'G'
      max = count_G
  if count_C > max:
      max_nucleotide = 'C'

  print(f"position {i+1} : {count_A} , {count_T} , {count_G} , {count_C}")

  consensus_sequence += max_nucleotide

print("Consensus Sequence:", consensus_sequence)
# Out:
# position 1 : 37 , 10 , 10 , 10
# position 2 : 10 , 37 , 10 , 10
# position 3 : 10 , 10 , 37 , 10
# position 4 : 10 , 10 , 10 , 37
# Consensus Sequence: ATGC

# %%
#Step 3: calculating hamming distance
if len(original_sequence) != len(consensus_sequence):
    print("Sequences are not of same length")
else:
  hamming_distance = 0
  for i in range(len(original_sequence)):
      if original_sequence[i] != consensus_sequence[i]:
          hamming_distance += 1

  print("Hamming Distance:", hamming_distance)
# Out:
# Hamming Distance: 0

# %% [markdown]
# Question 2 (5 points)
# Write a script to download any FASTQC file from NCBI GEO and perform the following QC checks:
# 1. Read length.
# 2. Number of reads.
# 3. Plot nucleotide distribution across locations of the reads. State your observations about biases, if
# any.

# %%
# !sudo apt install sra-toolkit

# %%
# !prefetch SRR390728
# Out:
# 2023-09-10T09:36:55 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2023-09-10T09:36:55 prefetch.2.11.3: 1) Downloading 'SRR390728'...
# 2023-09-10T09:36:55 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2023-09-10T09:36:55 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:01 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:03 prefetch.2.11.3:  'SRR390728' is valid
# 2023-09-10T09:37:03 prefetch.2.11.3: 1) 'SRR390728' was downloaded successfully
# 2023-09-10T09:37:07 prefetch.2.11.3: 'SRR390728' has 25 unresolved dependencies
# 2023-09-10T09:37:07 prefetch.2.11.3: 2) Downloading 'ncbi-acc:GPC_000000394.1?vdb-ctx=refseq'...
# 2023-09-10T09:37:07 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:07 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:07 prefetch.2.11.3: 2) 'ncbi-acc:GPC_000000394.1?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:07 prefetch.2.11.3: 3) Downloading 'ncbi-acc:GPC_000000395.1?vdb-ctx=refseq'...
# 2023-09-10T09:37:07 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:07 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:07 prefetch.2.11.3: 3) 'ncbi-acc:GPC_000000395.1?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:07 prefetch.2.11.3: 4) Downloading 'ncbi-acc:NC_000001.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:07 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:08 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:08 prefetch.2.11.3: 4) 'ncbi-acc:NC_000001.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:08 prefetch.2.11.3: 5) Downloading 'ncbi-acc:NC_000002.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:08 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:09 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:09 prefetch.2.11.3: 5) 'ncbi-acc:NC_000002.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:09 prefetch.2.11.3: 6) Downloading 'ncbi-acc:NC_000003.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:09 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:10 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:10 prefetch.2.11.3: 6) 'ncbi-acc:NC_000003.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:10 prefetch.2.11.3: 7) Downloading 'ncbi-acc:NC_000004.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:10 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:10 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:10 prefetch.2.11.3: 7) 'ncbi-acc:NC_000004.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:10 prefetch.2.11.3: 8) Downloading 'ncbi-acc:NC_000006.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:10 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:11 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:11 prefetch.2.11.3: 8) 'ncbi-acc:NC_000006.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:11 prefetch.2.11.3: 9) Downloading 'ncbi-acc:NC_000007.12?vdb-ctx=refseq'...
# 2023-09-10T09:37:11 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:11 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:11 prefetch.2.11.3: 9) 'ncbi-acc:NC_000007.12?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:11 prefetch.2.11.3: 10) Downloading 'ncbi-acc:NC_000008.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:11 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:12 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:12 prefetch.2.11.3: 10) 'ncbi-acc:NC_000008.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:12 prefetch.2.11.3: 11) Downloading 'ncbi-acc:NC_000009.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:12 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:13 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:13 prefetch.2.11.3: 11) 'ncbi-acc:NC_000009.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:13 prefetch.2.11.3: 12) Downloading 'ncbi-acc:NC_000010.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:13 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:13 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:13 prefetch.2.11.3: 12) 'ncbi-acc:NC_000010.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:13 prefetch.2.11.3: 13) Downloading 'ncbi-acc:NC_000011.8?vdb-ctx=refseq'...
# 2023-09-10T09:37:13 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:14 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:14 prefetch.2.11.3: 13) 'ncbi-acc:NC_000011.8?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:14 prefetch.2.11.3: 14) Downloading 'ncbi-acc:NC_000012.10?vdb-ctx=refseq'...
# 2023-09-10T09:37:14 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:14 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:14 prefetch.2.11.3: 14) 'ncbi-acc:NC_000012.10?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:14 prefetch.2.11.3: 15) Downloading 'ncbi-acc:NC_000013.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:14 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:15 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:15 prefetch.2.11.3: 15) 'ncbi-acc:NC_000013.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:15 prefetch.2.11.3: 16) Downloading 'ncbi-acc:NC_000014.7?vdb-ctx=refseq'...
# 2023-09-10T09:37:15 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:15 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:15 prefetch.2.11.3: 16) 'ncbi-acc:NC_000014.7?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:15 prefetch.2.11.3: 17) Downloading 'ncbi-acc:NC_000015.8?vdb-ctx=refseq'...
# 2023-09-10T09:37:15 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:15 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:15 prefetch.2.11.3: 17) 'ncbi-acc:NC_000015.8?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:15 prefetch.2.11.3: 18) Downloading 'ncbi-acc:NC_000016.8?vdb-ctx=refseq'...
# 2023-09-10T09:37:15 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:16 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:16 prefetch.2.11.3: 18) 'ncbi-acc:NC_000016.8?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:16 prefetch.2.11.3: 19) Downloading 'ncbi-acc:NC_000017.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:16 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:16 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:16 prefetch.2.11.3: 19) 'ncbi-acc:NC_000017.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:16 prefetch.2.11.3: 20) Downloading 'ncbi-acc:NC_000018.8?vdb-ctx=refseq'...
# 2023-09-10T09:37:16 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:18 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:18 prefetch.2.11.3: 20) 'ncbi-acc:NC_000018.8?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:18 prefetch.2.11.3: 21) Downloading 'ncbi-acc:NC_000019.8?vdb-ctx=refseq'...
# 2023-09-10T09:37:18 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:19 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:19 prefetch.2.11.3: 21) 'ncbi-acc:NC_000019.8?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:19 prefetch.2.11.3: 22) Downloading 'ncbi-acc:NC_000020.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:19 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:19 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:19 prefetch.2.11.3: 22) 'ncbi-acc:NC_000020.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:19 prefetch.2.11.3: 23) Downloading 'ncbi-acc:NC_000021.7?vdb-ctx=refseq'...
# 2023-09-10T09:37:19 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:19 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:19 prefetch.2.11.3: 23) 'ncbi-acc:NC_000021.7?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:19 prefetch.2.11.3: 24) Downloading 'ncbi-acc:NC_000022.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:19 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:19 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:19 prefetch.2.11.3: 24) 'ncbi-acc:NC_000022.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:19 prefetch.2.11.3: 25) Downloading 'ncbi-acc:NC_000023.9?vdb-ctx=refseq'...
# 2023-09-10T09:37:19 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:20 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:20 prefetch.2.11.3: 25) 'ncbi-acc:NC_000023.9?vdb-ctx=refseq' was downloaded successfully
# 2023-09-10T09:37:20 prefetch.2.11.3: 26) Downloading 'ncbi-acc:NC_001807.4?vdb-ctx=refseq'...
# 2023-09-10T09:37:20 prefetch.2.11.3:  Downloading via HTTPS...
# 2023-09-10T09:37:20 prefetch.2.11.3:  HTTPS download succeed
# 2023-09-10T09:37:20 prefetch.2.11.3: 26) 'ncbi-acc:NC_001807.4?vdb-ctx=refseq' was downloaded successfully

# %%
# !cd SRR390728/
# !ls SRR390728/
# Out:
# GPC_000000394.1  NC_000006.10  NC_000012.10  NC_000018.8  NC_001807.4
# GPC_000000395.1  NC_000007.12  NC_000013.9   NC_000019.8  SRR390728.sra
# NC_000001.9	 NC_000008.9   NC_000014.7   NC_000020.9
# NC_000002.10	 NC_000009.10  NC_000015.8   NC_000021.7
# NC_000003.10	 NC_000010.9   NC_000016.8   NC_000022.9
# NC_000004.10	 NC_000011.8   NC_000017.9   NC_000023.9

# %%
# !ls
# Out:
# sample_data  SRR390728

# %%
# !fastq-dump --outdir fastq --gzip --skip-technical  --readids --read-filter pass --dumpbase --split-3 --clip SRR390728/SRR390728.sra
# Out:
# Read 7178576 spots for SRR390728/SRR390728.sra
# Written 6649544 spots for SRR390728/SRR390728.sra

# %%
# !ls fastq/
# Out:
# SRR390728_pass_1.fastq.gz  SRR390728_pass_2.fastq.gz

# %%
# !gzip -d fastq/SRR390728_pass_1.fastq.gz

# %%
# !ls fastq/
# Out:
# SRR390728_pass_1.fastq	SRR390728_pass_2.fastq.gz

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.23.5)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
from Bio import SeqIO

sequence_count = 0
sequence_length =0;

with open('fastq/SRR390728_pass_1.fastq', 'r') as fq_file:
    for record in SeqIO.parse(fq_file, 'fastq'):
        sequence_count = sequence_count+ 1
        sequence_length = len(record.seq)

print(f"Number of sequences in Fastq file: {sequence_count}")
print(f"Length of sequences in Fastq File: {sequence_length}")
# Out:
# Number of sequences in Fastq file: 6649544
# Length of sequences in Fastq File: 36

# %%
import matplotlib.pyplot as plt
from Bio import SeqIO
from collections import defaultdict

nucleotide_symbols = ['A', 'T', 'G', 'C']
position_counts = defaultdict(lambda: defaultdict(int))
sequence_length = 0
sequence_count = 0

with open('fastq/SRR390728_pass_1.fastq', 'r') as fq_file:
    for record in SeqIO.parse(fq_file, 'fastq'):
        sequence_count+=1
        if sequence_length ==0:
            sequence_length = len(record.seq)
            position_counts = defaultdict(lambda: defaultdict(int))

            for i in range(1, sequence_length):
                position_counts[i] = defaultdict(int)

        for i, nucleotide in enumerate(record.seq):
            if nucleotide not in nucleotide_symbols:
                nucleotide = 'Other'
            position_counts[i][nucleotide] += 1

position_percentages = defaultdict(lambda: defaultdict(float))
for position in range(sequence_length):
    total_counts = sum(position_counts[position].values())
    for nucleotide in nucleotide_symbols + ['Other']:
        position_percentages[position][nucleotide] = (position_counts[position][nucleotide] / sequence_count)
        position_percentages[position][nucleotide] *=100

positions = range(sequence_length)

for nucleotide in nucleotide_symbols + ['Other']:
    percentages = [position_percentages[position][nucleotide] for position in positions]
    plt.plot(positions, percentages, label=nucleotide)

plt.title('Nucleotide Percentage Across Positions')
plt.xlabel('Position')
plt.ylabel('Percentage (%)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Question 3 (5 points)
# Generate 100 random 1KB sequences (as if they are upstream of some genes, you can use real data from
# UCSC for some co-regulated genes as well). Plant a motif of length 10 after introducing 0, 1, 2 random
# mutations (uniformly distributed). Use Gibbs sampler to identify the motif locations and the consensus
# motif.

# %%
from random import randrange
print(randrange(10))
# Out:
# 8

# %%
nucleotides = ['A','T','G','C']

seq_length = 10**4 # 10 thousand (10KB sequences)

# generate random sequence of length 10,000

num_sequences = 100
sequences = []

for i in range(num_sequences):
    seq = ""
    for j in range(seq_length):
        seq += nucleotides[randrange(4)]
    sequences.append(seq)

print("Number of sequences : ",len(list(set(sequences))))
# => all sequences are unique and random
# Out:
# Number of sequences :  100

# %%
print(len(sequences))
print(len(set(sequences)))
# Out:
# 100
# 100

# %%
def one_random_mutation(s):
    pos_of_mutation = randrange(10)
    base_of_mutation = nucleotides[randrange(4)]

    list_s = list(s)
    list_s[pos_of_mutation] = base_of_mutation

    return "".join(list_s)

def two_random_mutation(s):
    pos1_of_mutation = randrange(10)
    pos2_of_mutation = randrange(10)

    base1_of_mutation = nucleotides[randrange(4)]
    base2_of_mutation = nucleotides[randrange(4)]

    list_s = list(s)
    list_s[pos1_of_mutation] = base1_of_mutation
    list_s[pos2_of_mutation] = base2_of_mutation

    return "".join(list_s)

# %%
# 10 length motif
consensus_motif = "AGCTACTAAC"

# 1 random mutation , 2 random mutation

print("After one random mutation : ",one_random_mutation(consensus_motif))
print("After one random mutation : ",one_random_mutation(consensus_motif))
print("After two random mutation : ",two_random_mutation(consensus_motif))
print("After two random mutation : ",two_random_mutation(consensus_motif))
# Out:
# After one random mutation :  AGCTATTAAC
# After one random mutation :  AGCTACTAAC
# After two random mutation :  AGGTAGTAAC
# After two random mutation :  GGCTACTAAC

# %%
# sequences after the planting of motif are store in this
after_motif_planted_seqs = []

# Just to store the answer of the motif locations
actual_positions_of_motifs = []


# Planting motif
for i in range(len(sequences)):

    # IMP : last where the motif can be planted is at 89 as length is 10
    start_point_motif = randrange(9990)

    actual_positions_of_motifs.append(start_point_motif)

    list_seq = list(sequences[i])

    # if mutation_to_choose = 0 , then 0 mutate and plant
    # if 1 then one mutate and plant
    # if 2 then two mutate and plant
    mutation_to_choose = randrange(3)

    if mutation_to_choose == 0:
      list_seq[start_point_motif:start_point_motif+10] = consensus_motif
    elif mutation_to_choose == 0:
      list_seq[start_point_motif:start_point_motif+10] = one_random_mutation(consensus_motif)
    else:
      list_seq[start_point_motif:start_point_motif+10] = two_random_mutation(consensus_motif)

    planted_seq = "".join(list_seq)

    after_motif_planted_seqs.append(planted_seq)

print(len(set(after_motif_planted_seqs)))
print(actual_positions_of_motifs)
# Out:
# 100
# [5091, 9586, 1700, 2516, 4089, 7502, 8072, 2611, 4749, 8478, 4891, 2381, 9016, 8752, 4464, 194, 7801, 8116, 8985, 1635, 2144, 6497, 5640, 2549, 4154, 3837, 1356, 4356, 7350, 4229, 9363, 5565, 9912, 3717, 2058, 8456, 6949, 4414, 9749, 2492, 6814, 2295, 6033, 8844, 7399, 7453, 4051, 2484, 2616, 3523, 5477, 1951, 268, 4319, 2126, 6626, 5879, 7908, 4228, 6788, 373, 3987, 4695, 670, 9485, 2831, 5306, 627, 2973, 1287, 9243, 7421, 5124, 6120, 416, 29, 2758, 3291, 8171, 5034, 7529, 5851, 803, 8175, 8248, 8471, 5118, 8484, 4667, 7299, 3677, 3602, 7541, 3787, 7743, 7716, 9986, 5226, 3494, 2140]

# %% [markdown]
# GIBBS SAMPLING ALGORITHM ON after_motif_planted_seqs

# %%
# STEP 1 : assign random start sights to the motifs in each sequence

random_start_sights_motifs = []

for i in range(100):
    random_start_sights_motifs.append(randrange(9988))

print(len(random_start_sights_motifs))
print(random_start_sights_motifs)
# Out:
# 100
# [7046, 4411, 7802, 9621, 6581, 1288, 1977, 5131, 6036, 6885, 4927, 8336, 586, 7777, 4799, 3109, 8946, 4741, 9527, 2688, 1691, 5097, 5878, 9152, 6907, 6986, 4194, 5359, 3653, 8057, 7534, 1903, 4638, 7544, 3329, 9102, 8494, 2206, 7632, 9442, 1782, 3088, 3862, 7407, 1885, 8637, 6275, 9038, 337, 2099, 3065, 700, 1172, 4155, 5934, 9331, 1337, 8439, 9648, 3718, 9644, 8036, 9333, 969, 5862, 6614, 4256, 6469, 9719, 4638, 4245, 7295, 3348, 2201, 254, 7700, 4867, 4159, 9155, 3446, 477, 1426, 5398, 8543, 4284, 5215, 9613, 6688, 2746, 6690, 7031, 1923, 1678, 3812, 8722, 1886, 6558, 9745, 258, 1365]

# %% [markdown]
# Functions for calculating hamming distance between motifs

# %%
def hamming(s1,s2):
    score = 0
    if s1 == "" or s2 == "":
        return 0
    for i in range(len(s1)):
        if s1[i] != s2[i]:
          score +=1
    return score

def calculateHamming(after_motif_planted_seqs,random_start_sights_motifs):
    # 100 motifs
    current_motifs = []
    for i in range(100):
        s = random_start_sights_motifs[i]
        current_motifs.append(after_motif_planted_seqs[i][s:s+10])
    hamming_distance = 0
    for i in range(len(current_motifs)):
        for j in range(i+1,len(current_motifs)):
            dist = hamming(current_motifs[i],current_motifs[j])
            hamming_distance += dist

    # avergae hamming
    return hamming_distance/100

# %% [markdown]
# build_profile_matrix prepares the profile matrix for each iteration using
#
# motif sequences in the current iteration

# %%
def print_profile_matrix(profile_matrix):
     print(f"Profile matrix at iteration {c} :-")
     for i in range(4):
          for j in range(10):
              print(profile_matrix[i][j],end = " ")
          print()

# %%
from random import randrange

    # Profile matrix

    # A T A G C T
    # A G C T A C
    # G T A C T T                      matrix size = 4 rows and 10 columns
# A  2/3                               A : [0][i]
# T                                    B : [1][i]
# G                                    C : [2][i]
# C                                    D : [3][i]

# sequences : after_motif_planted_seqs
random_start_sights_motifs = []

for i in range(100):
    random_start_sights_motifs.append(randrange(9990))

num_iterations = 1000
c = 1

original_random_start_copy = random_start_sights_motifs.copy()

while c <= num_iterations:
    print("ITERATION NO. : ",c)

    profile_matrix = [[1e-10] * 10 for _ in range(4)]

    # STEP 2 : At random select a sequence from the given 't' sequences and
    # make a profile matrix out of the other 't-1' sequences
    random_selected = randrange(100)
    # print("selected sequence of 100 : ",random_selected)
    selected_seq = after_motif_planted_seqs[random_selected]

    # current motifs are the motif sequence of 100 sequences
    #in accordance with the current start
    # positions of the motifs
    current_motifs = []

    for i in range(100):
        if i == random_selected:
           continue
        # i in the sequnence we want to extract the current motif
        si = random_start_sights_motifs[i]
        current_motifs.append(after_motif_planted_seqs[i][si:si+10])

    current_motifs = [s for s in current_motifs if s.strip()]
    # create a profile for these 100 motifs of length 10
    # print_profile_matrix(profile_matrix)
    k = 0
    while(k < 10):
      for i in range(len(current_motifs)):
        # this is the ith position
        if(current_motifs[i][k] == 'A'):
            profile_matrix[0][k] += 1
        elif current_motifs[i][k] == 'T':
            profile_matrix[1][k] += 1
        elif current_motifs[i][k] == 'G':
            profile_matrix[2][k] += 1
        elif current_motifs[i][k] == 'C':
            profile_matrix[3][k] += 1
      k+=1
    # divide all of the values in the matrix by 100 to create probabilities
    for i in range(4):
        for j in range(10):
           profile_matrix[i][j] /= 100

    # print_profile_matrix(profile_matrix)

    # Now use the profile for the t-th sequence probablities
    # This contains probabilities of all the l-mers from the selected sequence
    # key is the start pos of lmer and value is the probability

    probabilities_lmers = {}

    k = 0
    while(k <= 9990):
      lmer = selected_seq[k:k+10]
      prob = 1
      for i in range(len(lmer)):
          if lmer[i] == 'A':
              prob = prob*profile_matrix[0][i]
          elif lmer[i] == 'T':
              prob = prob*profile_matrix[1][i]
          elif lmer[i] == 'G':
              prob = prob*profile_matrix[2][i]
          elif lmer[i] == 'C':
              prob = prob*profile_matrix[3][i]
      k+=10
      probabilities_lmers[k] = prob

    # find the lowest prob and dividing all by this
    lowest_prob = min(probabilities_lmers.values())
    sum_prob = sum(probabilities_lmers.values())

    for start,prob in probabilities_lmers.items():
        probabilities_lmers[start] /= lowest_prob
        probabilities_lmers[start] /= sum_prob

    # now select the max prob from the prob_dist
    # index of the max value
    max_prob_start_loc = max(probabilities_lmers, key=lambda k: probabilities_lmers[k])

    # Now update the start sight of the random selected seq to the
    # index value in the sequence with max

    print(f"start loc of index no. {random_selected} changed to {max_prob_start_loc} from {random_start_sights_motifs[random_selected]}")

    print(f"motif original start postitions:-")
    print(original_random_start_copy)

    before = random_start_sights_motifs
    random_start_sights_motifs[random_selected] = max_prob_start_loc

    print(f"start positions after iteration {c} :-")
    print(random_start_sights_motifs)

    diff = [x - y for x, y in zip(original_random_start_copy,before)]
    count_of_zeroes = diff.count(0)
    print(f"count of zero score at iteration {c} : {count_of_zeroes}")
    # hypothesis is these zeroes should reduce with iterations

    # calculate score
    # score I have defined as sum of hamming distance b/w motifs should be minimum
    score = calculateHamming(after_motif_planted_seqs,random_start_sights_motifs)
    print(f"score at iteration {c} is : {score}")

    print()
    print()

    c+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# ITERATION NO. :  501
# start loc of index no. 42 changed to 9430 from 9620
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 501 :-
# [7140, 2750, 4380, 8380, 100, 6090, 7320, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 1630, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1810, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 5800, 7560, 7550, 7900, 4960, 4060, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 501 : 0
# score at iteration 501 is : 370.92
#
#
# ITERATION NO. :  502
# start loc of index no. 75 changed to 7040 from 5800
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 502 :-
# [7140, 2750, 4380, 8380, 100, 6090, 7320, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 1630, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1810, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 4060, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 502 : 0
# score at iteration 502 is : 370.92
#
#
# ITERATION NO. :  503
# start loc of index no. 60 changed to 1590 from 1810
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 503 :-
# [7140, 2750, 4380, 8380, 100, 6090, 7320, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 1630, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 4060, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 503 : 0
# score at iteration 503 is : 370.79
#
#
# ITERATION NO. :  504
# start loc of index no. 6 changed to 2370 from 7320
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 504 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 1630, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 4060, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 504 : 0
# score at iteration 504 is : 370.91
#
#
# ITERATION NO. :  505
# start loc of index no. 80 changed to 3390 from 4060
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 505 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 1630, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 505 : 0
# score at iteration 505 is : 370.72
#
#
# ITERATION NO. :  506
# start loc of index no. 28 changed to 7550 from 1630
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 506 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 1500, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 506 : 0
# score at iteration 506 is : 370.44
#
#
# ITERATION NO. :  507
# start loc of index no. 43 changed to 8170 from 1500
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 507 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 8170, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 1200, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 507 : 0
# score at iteration 507 is : 370.4
#
#
# ITERATION NO. :  508
# start loc of index no. 64 changed to 3940 from 1200
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 508 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 8170, 2740, 6350, 4360, 4440, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 508 : 0
# score at iteration 508 is : 370.47
#
#
# ITERATION NO. :  509
# start loc of index no. 47 changed to 9320 from 4440
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 509 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 980, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 509 : 0
# score at iteration 509 is : 370.46
#
#
# ITERATION NO. :  510
# start loc of index no. 56 changed to 9630 from 980
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 510 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 8790, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 510 : 0
# score at iteration 510 is : 370.53
#
#
# ITERATION NO. :  511
# start loc of index no. 41 changed to 1660 from 8790
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 511 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 720, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 511 : 0
# score at iteration 511 is : 370.44
#
#
# ITERATION NO. :  512
# start loc of index no. 27 changed to 1730 from 720
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 512 :-
# [7140, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 512 : 0
# score at iteration 512 is : 370.26
#
#
# ITERATION NO. :  513
# start loc of index no. 0 changed to 5600 from 7140
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 513 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 6770, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 513 : 0
# score at iteration 513 is : 370.2
#
#
# ITERATION NO. :  514
# start loc of index no. 37 changed to 1980 from 6770
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 514 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 360, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 514 : 0
# score at iteration 514 is : 369.94
#
#
# ITERATION NO. :  515
# start loc of index no. 74 changed to 2890 from 360
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 515 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 8180, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 515 : 0
# score at iteration 515 is : 370.15
#
#
# ITERATION NO. :  516
# start loc of index no. 84 changed to 5360 from 8180
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 516 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 2620, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 516 : 0
# score at iteration 516 is : 370.29
#
#
# ITERATION NO. :  517
# start loc of index no. 63 changed to 8390 from 2620
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 517 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 150, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 517 : 0
# score at iteration 517 is : 370.62
#
#
# ITERATION NO. :  518
# start loc of index no. 82 changed to 5700 from 150
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 518 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 800, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 518 : 0
# score at iteration 518 is : 370.93
#
#
# ITERATION NO. :  519
# start loc of index no. 92 changed to 9980 from 800
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 519 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 2890, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 519 : 0
# score at iteration 519 is : 371.22
#
#
# ITERATION NO. :  520
# start loc of index no. 16 changed to 1680 from 2890
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 520 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 8620, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 520 : 0
# score at iteration 520 is : 370.99
#
#
# ITERATION NO. :  521
# start loc of index no. 18 changed to 3610 from 8620
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 521 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 521 : 0
# score at iteration 521 is : 371.17
#
#
# ITERATION NO. :  522
# start loc of index no. 18 changed to 3610 from 3610
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 522 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 2710, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 522 : 0
# score at iteration 522 is : 371.17
#
#
# ITERATION NO. :  523
# start loc of index no. 25 changed to 9700 from 2710
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 523 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 6610, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 523 : 0
# score at iteration 523 is : 370.93
#
#
# ITERATION NO. :  524
# start loc of index no. 38 changed to 9790 from 6610
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 524 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 3810, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 524 : 0
# score at iteration 524 is : 371.08
#
#
# ITERATION NO. :  525
# start loc of index no. 83 changed to 1240 from 3810
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 525 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 1240, 5360, 7030, 6860, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 525 : 0
# score at iteration 525 is : 371.08
#
#
# ITERATION NO. :  526
# start loc of index no. 86 changed to 6110 from 6860
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 526 :-
# [5600, 2750, 4380, 8380, 100, 6090, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 526 : 0
# score at iteration 526 is : 371.14
#
#
# ITERATION NO. :  527
# start loc of index no. 5 changed to 4570 from 6090
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 527 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 8370, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 527 : 0
# score at iteration 527 is : 371.0
#
#
# ITERATION NO. :  528
# start loc of index no. 39 changed to 9270 from 8370
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 528 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 9270, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 3390, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 528 : 0
# score at iteration 528 is : 370.94
#
#
# ITERATION NO. :  529
# start loc of index no. 80 changed to 6510 from 3390
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 529 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 9270, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 529 : 0
# score at iteration 529 is : 371.06
#
#
# ITERATION NO. :  530
# start loc of index no. 60 changed to 1590 from 1590
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 530 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 9270, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 530 : 0
# score at iteration 530 is : 371.06
#
#
# ITERATION NO. :  531
# start loc of index no. 25 changed to 9700 from 9700
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 531 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 9270, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 531 : 0
# score at iteration 531 is : 371.06
#
#
# ITERATION NO. :  532
# start loc of index no. 39 changed to 7290 from 9270
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 532 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 6430, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 7290, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 532 : 0
# score at iteration 532 is : 370.88
#
#
# ITERATION NO. :  533
# start loc of index no. 13 changed to 9960 from 6430
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 533 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 9960, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 7290, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 8390, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 533 : 0
# score at iteration 533 is : 371.01
#
#
# ITERATION NO. :  534
# start loc of index no. 63 changed to 3560 from 8390
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 534 :-
# [5600, 2750, 4380, 8380, 100, 4570, 2370, 7830, 8110, 1440, 3510, 6790, 600, 9960, 7370, 7370, 1680, 2670, 3610, 8310, 4190, 3880, 7870, 930, 740, 9700, 6570, 1730, 7550, 9450, 7430, 6760, 7450, 2570, 1460, 8410, 8980, 1980, 9790, 7290, 2050, 1660, 9430, 8170, 2740, 6350, 4360, 9320, 8220, 5300, 990, 4230, 8790, 4600, 1670, 170, 9630, 2750, 5020, 510, 1590, 6520, 510, 3560, 3940, 590, 7260, 7350, 3170, 5760, 5600, 4110, 640, 1530, 2890, 7040, 7560, 7550, 7900, 4960, 6510, 2630, 5700, 1240, 5360, 7030, 6110, 9540, 330, 2470, 1370, 8520, 9980, 2550, 3700, 8560, 3830, 8980, 9070, 2410]
# count of zero score at iteration 534 : 0
# score at iteration 534 is : 370.8
#
#
# ITERATION NO. :  535
# start loc of index no. 60 changed to 4600 from 1590
# motif original start postitions:-
# ...
# count of zero score at iteration 989 : 0
# score at iteration 989 is : 370.43
#
#
# ITERATION NO. :  990
# start loc of index no. 44 changed to 3230 from 7550
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 990 :-
# [1330, 7700, 9420, 2290, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 3150, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 4200, 8650, 8530, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 990 : 0
# score at iteration 990 is : 370.78
#
#
# ITERATION NO. :  991
# start loc of index no. 3 changed to 7160 from 2290
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 991 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 3150, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 4200, 8650, 8530, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 991 : 0
# score at iteration 991 is : 370.72
#
#
# ITERATION NO. :  992
# start loc of index no. 78 changed to 9360 from 4200
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 992 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 3150, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 9360, 8650, 8530, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 992 : 0
# score at iteration 992 is : 370.73
#
#
# ITERATION NO. :  993
# start loc of index no. 51 changed to 3140 from 3140
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 993 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 3150, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 9360, 8650, 8530, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 993 : 0
# score at iteration 993 is : 370.73
#
#
# ITERATION NO. :  994
# start loc of index no. 45 changed to 9740 from 3150
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 994 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 9360, 8650, 8530, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 994 : 0
# score at iteration 994 is : 370.84
#
#
# ITERATION NO. :  995
# start loc of index no. 80 changed to 8180 from 8530
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 995 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 160, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 995 : 0
# score at iteration 995 is : 370.93
#
#
# ITERATION NO. :  996
# start loc of index no. 10 changed to 3520 from 160
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 996 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 9980, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 996 : 0
# score at iteration 996 is : 370.9
#
#
# ITERATION NO. :  997
# start loc of index no. 74 changed to 5090 from 9980
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 997 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 8820, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 5090, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 997 : 0
# score at iteration 997 is : 370.71
#
#
# ITERATION NO. :  998
# start loc of index no. 38 changed to 9270 from 8820
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 998 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 6270, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 9270, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 5090, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 998 : 0
# score at iteration 998 is : 370.82
#
#
# ITERATION NO. :  999
# start loc of index no. 11 changed to 2600 from 6270
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 999 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 2600, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 9270, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 8530, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 5090, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 999 : 0
# score at iteration 999 is : 371.13
#
#
# ITERATION NO. :  1000
# start loc of index no. 48 changed to 5510 from 8530
# motif original start postitions:-
# [6019, 7141, 253, 7151, 6645, 4781, 417, 2891, 8077, 5913, 3796, 850, 1733, 769, 4424, 6913, 478, 5646, 4746, 2243, 2256, 1079, 206, 9494, 5777, 6638, 4802, 4864, 9379, 8513, 9015, 1035, 1609, 3210, 4030, 9195, 8740, 9710, 1108, 4712, 2058, 2631, 4158, 1712, 3709, 720, 6641, 2672, 3056, 7970, 3635, 4856, 5271, 1226, 7865, 8659, 8715, 3349, 5763, 5395, 6828, 911, 5183, 8257, 2074, 1760, 9298, 854, 1679, 6269, 8670, 6039, 6083, 2553, 2637, 9861, 2975, 5122, 2472, 8226, 6160, 2488, 3065, 4421, 2372, 3387, 1643, 2959, 2818, 7309, 9809, 8480, 8212, 764, 6308, 5304, 8373, 6753, 6535, 6179]
# start positions after iteration 1000 :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 2600, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 9270, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 5510, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 5090, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
# count of zero score at iteration 1000 : 0
# score at iteration 1000 is : 371.37

# %%
print("Actual locations :-")
print(actual_positions_of_motifs)
print("After 1000 iterations :- ")
print(random_start_sights_motifs)
# Out:
# Actual locations :-
# [5091, 9586, 1700, 2516, 4089, 7502, 8072, 2611, 4749, 8478, 4891, 2381, 9016, 8752, 4464, 194, 7801, 8116, 8985, 1635, 2144, 6497, 5640, 2549, 4154, 3837, 1356, 4356, 7350, 4229, 9363, 5565, 9912, 3717, 2058, 8456, 6949, 4414, 9749, 2492, 6814, 2295, 6033, 8844, 7399, 7453, 4051, 2484, 2616, 3523, 5477, 1951, 268, 4319, 2126, 6626, 5879, 7908, 4228, 6788, 373, 3987, 4695, 670, 9485, 2831, 5306, 627, 2973, 1287, 9243, 7421, 5124, 6120, 416, 29, 2758, 3291, 8171, 5034, 7529, 5851, 803, 8175, 8248, 8471, 5118, 8484, 4667, 7299, 3677, 3602, 7541, 3787, 7743, 7716, 9986, 5226, 3494, 2140]
# After 1000 iterations :-
# [1330, 7700, 9420, 7160, 8090, 8930, 1300, 8590, 3400, 6660, 3520, 2600, 8310, 7640, 3480, 6520, 4960, 5380, 6150, 7040, 1260, 3510, 6610, 6290, 5480, 4660, 9500, 8450, 1170, 170, 5370, 9010, 1190, 1460, 7440, 5580, 870, 8200, 9270, 7920, 4570, 3670, 5340, 2420, 3230, 9740, 7800, 3020, 5510, 1940, 6700, 3140, 8280, 8320, 6390, 980, 3880, 6230, 2230, 5340, 590, 6600, 1620, 3150, 3600, 6120, 2820, 500, 170, 3270, 310, 7560, 1660, 8580, 5090, 4150, 4270, 9600, 9360, 8650, 8180, 3010, 8530, 5510, 3250, 5680, 9900, 4690, 9670, 7440, 1010, 1820, 7000, 2120, 1580, 9800, 5730, 6230, 1600, 4870]
